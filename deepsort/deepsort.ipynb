# %%
# !git clone https://github.com/theAIGuysCode/yolov4-deepsort
# Out:
# Cloning into 'yolov4-deepsort'...
# remote: Enumerating objects: 143, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 143 (delta 1), reused 1 (delta 0), pack-reused 137
# Receiving objects: 100% (143/143), 76.84 MiB | 2.70 MiB/s, done.
# Resolving deltas: 100% (40/40), done.

# %%
# %cd yolov4-deepsort/
# Out:
# /Users/mihirshah/Desktop/deepsort/yolov4-deepsort

# %%
pip install easydict
# Out:
# ...
#   Created wheel for easydict: filename=easydict-1.9-py3-none-any.whl size=6350 sha256=03e612e62022c54caf507b3bde84a30d10d4dc9aaf01a2b5bf7bcf14543429a5
#   Stored in directory: /Users/mihirshah/Library/Caches/pip/wheels/88/96/68/c2be18e7406804be2e593e1c37845f2dd20ac2ce1381ce40b0
# Successfully built easydict
# ...
# WARNING: You are using pip version 21.0.1; however, version 21.3.1 is available.
# You should consider upgrading via the '/opt/anaconda3/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python save_model.py --model yolov4
# Out:
# 2021-11-25 18:34:22.525399: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-11-25 18:34:22.525851: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 416, 416, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 416, 416, 32) 864         input_1[0][0]
# ...

# %%
# !python object_tracker.py --video ./data/video/test.mp4 --output ./outputs/trafficdemooutput.avi --model yolov4 --dont_show --info
# Out:
# Frame #:  1
# FPS: 0.29
# Frame #:  2
# FPS: 0.77
# Frame #:  3
# FPS: 0.78
# Frame #:  4
# FPS: 1.01
# Frame #:  5
# FPS: 0.90
# Frame #:  6
# FPS: 0.81
# Frame #:  7
# FPS: 1.04
# Frame #:  8
# FPS: 1.04
# Frame #:  9
# FPS: 0.56
# Frame #:  10
# FPS: 0.90
# Frame #:  11
# FPS: 0.77
# Frame #:  12
# FPS: 0.98
# Frame #:  13
# FPS: 0.83
# Frame #:  14
# FPS: 1.01
# Frame #:  15
# FPS: 0.76
# Frame #:  16
# FPS: 0.97
# Frame #:  17
# FPS: 0.79
# Frame #:  18
# FPS: 0.99
# Frame #:  19
# FPS: 0.78
# Frame #:  20
# FPS: 0.99
# Frame #:  21
# FPS: 0.98
# Frame #:  22
# FPS: 0.77
# Frame #:  23
# FPS: 0.83
# Frame #:  24
# FPS: 0.86
# Frame #:  25
# FPS: 0.65
# Frame #:  26
# FPS: 0.75
# Frame #:  27
# FPS: 0.84
# Frame #:  28
# FPS: 0.97
# Frame #:  29
# FPS: 0.75
# Frame #:  30
# FPS: 0.96
# Frame #:  31
# FPS: 0.92
# Frame #:  32
# FPS: 0.76
# Frame #:  33
# FPS: 0.93
# Frame #:  34
# FPS: 0.75
# Frame #:  35
# FPS: 0.93
# Frame #:  36
# FPS: 0.96
# Frame #:  37
# FPS: 0.75
# ...
